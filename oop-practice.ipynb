# %%
class bank :
    def __init__(self):
        self.pin= None
        self.balance=None
    def menu(self):
        while(True) :
         choice=int(input("Enter the num for your choice  0->Exit  1->show balance  2->set pin  3->deposite  4->withdraw "))
         if choice==0:
           break
         
         elif choice==1:
            if self.pin==None and self.balance==None :
              print("New User! ...First set your pin and deposite some amount ")
              self.setpin()
              self.deposite()
            elif self.pin!=None and self.balance==None:
              print(" You have no amount in your balance , deposite some amount")
              self.deposite()
              self.showbalance()
            else :
              x=input(int( "Enter your Pin"))
              user1.showbalance()
         elif choice==2:
              user1.setpin(x)
         elif choice==3: 
           x=input(int( "Enter your Pin"))
           if user1.balance==0:
            print("Your current balance is zero") 
            user1.deposite()
           else:      
            user1.deposite()  
         elif choice==4:
            if self.pin==None and self.balance==None :
              print("New User! ...First set your pin and deposite some amount ")
              self.setpin()
              self.deposite()
              self.withdraw()
            elif self.pin!=None and self.balance==None:
              print(" You have no amount in your balance , deposite some amount")
              self.deposite()
              self.showbalance()
              self.withdraw()
            else :
              x=input(int( "Enter your Pin"))
              user1.withdraw()
         else:
          print("Invalid choice") 
    def setpin(self) :
        
        pin=int(input("Enter your pin"))
        self.pin=pin
    
    def showbalance(self):
        print(self.balance)
    
    def deposite(self):
        amount=input(int( "Enter amount")) 
        self.balance += amount
    def withdraw(self) :
        amount=input(int( "Enter amount")) 
        self.balance -=amount
user1=bank()
user1.menu()
# Out:
# New User! ...First set your pin and deposite some amount
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 63
#      61         self.balance -=amount
#      62 user1=bank()
# ---> 63 user1.menu()
#
# Cell In[2], line 15, in bank.menu(self)
#      13   print("New User! ...First set your pin and deposite some amount ")
#      14   self.setpin()
# ---> 15   self.deposite()
#      16 elif self.pin!=None and self.balance==None:
#      17   print(" You have no amount in your balance , deposite some amount")
#
# Cell In[2], line 57, in bank.deposite(self)
#      56 def deposite(self):
# ---> 57     amount=input(int( "Enter amount"))
#      58     self.balance += amount
#
# ValueError: invalid literal for int() with base 10: 'Enter amount'

# %%
class animal:
    def __init__(self):
      self.animal=["cat","lion","dog","monkey","deer","tiger","hen"]
      self.voice=["meow...","roar...!","bow wow!","Kee-kee-kee!","Meee…","Grrrrrr…","Cluck-cluck-cluck!"]
      
      
    def voic(self): 
        k=-1
        self.name=str(input("Enter animal name"))
        self.name=self.name.lower()
        for i in range(len(self.animal)) :
           if self.animal[i] == self.name :
              k=i 
           
        if k!=-1 :
             print("The voice of ",self.name, "is ",self.voice[k])
        else:
              print("your entered animal is not found on list, list upgraded succesfully")
              self.animal.append(self.name)
              print(self.animal)

obj1=animal()
obj1.voic()
# Out:
# your entered animal is not found on list, list upgraded succesfully
# ['cat', 'lion', 'dog', 'monkey', 'deer', 'tiger', 'hen', 'peocoke']

# %%
class clg:
   def __init__(self):
     self.dep={"CS":"ayesha","IT":"Fatima","MATH":"amna","PHYSICS":"tehreem"}
    # self.dep=["CS","IT", "physic","math","chemistry"] 
     #self.student=["fatima","ayesha","rimsha","amna","tehreem"]
   def ser(self) :
      self.name=str(input("Enter the student  name")).upper()
     # self.name=self.name.upper()
     
     # for i in range(len(self.student)) :
       # if self.student[i] == self.name:
         # k=i
      #if k!=-1 :
      if self.name in self.dep :
        print("the corresponding student" , self.name, "is in department",self.dep[self.name])
      else :
         print("not found")
u1=clg()
u1.ser()
# Out:
# the corresponding student MATH is in department amna
