# %%
class vehicle:
    def __init__(self,brand) :
        self.brand=brand
        
    def start(self):
        print("vehicle started")
class car(vehicle):
    def __init__(self,brand, model):
        self.model=model
        super().__init__(brand)
    def showinfo(self):
        print("brand is ",self.brand,"Model is",self.model)  
    def drive(self):
        print("car is driving")

x=car("fortuner",2010)
x.showinfo()
# Out:
# brand is  fortuner Model is 2001

# %%
class comp:
    def __init__(self,name,location):
       self.name=name
       self.location=location
       print("company created")
    def companyinfo(self):
        print(self.name,"techsoft",self.company,"Lahore")
        print("working hours are 9am to 5 am")
class employee(comp):
        def __init__(self,name,location,salary,):
            self.salary=salary
            super().__init__(name,location)
        def show(self):
             print(self.location,self.name,self.salary)
x=employee("vokj","lahore",6789) 
x.show()
# Out:
# company created
# lahore vokj 6789

# %%
class Employee:
    
    def __init__(self, name, employee_id, salary):
        # Private attributes (encapsulation)
        self.__name = name              # Private (double underscore)
        self.__employee_id = employee_id # Private
        self.__salary = salary           # Private
        self._department = "General"     # Protected (single underscore)
    
    # Getter methods (encapsulation)
    def get_name(self):
        return self.__name
    
    def get_employee_id(self):
        return self.__employee_id
    
    def get_salary(self):
        return self.__salary
    
    def get_department(self):
        return self._department
    
    # Setter methods with validation (encapsulation)
    def set_salary(self, new_salary):
        if new_salary > 0:
            self.__salary = new_salary
            return True
        else:
            print("Salary must be positive!")
            return False
    
    def set_department(self, new_department):
        self._department = new_department
    
    # Public methods
    def calculate_bonus(self):
        """Calculate bonus (5% of salary)"""
        return self.__salary * 0.05
    
    def display_info(self):
        """Display employee information"""
        print(f"Name: {self.__name}")
        print(f"Employee ID: {self.__employee_id}")
        print(f"Department: {self._department}")
        print(f"Salary: ${self.__salary:,.2f}")
        print(f"Bonus: ${self.calculate_bonus():,.2f}")


# Create an employee object
emp = Employee("Alice", "E123", 75000)
emp.calculate_bonus()
emp.__name='ali'
emp.get_name()
class Manager(Employee):
    
    def __init__(self, name, employee_id, salary, team_size):
        # Call parent class constructor
        super().__init__(name, employee_id, salary)
        self.__team_size = team_size      # Private attribute
        self.set_department("Management") # Using parent's protected method
    
    # Additional methods specific to Manager
    def get_team_size(self):
        return self.__team_size
    
    def set_team_size(self, new_size):
        if new_size > 0:
            self.__team_size = new_size
            return True
        return False
    
    # # Override parent method (polymorphism)
    # def calculate_bonus(self):
    #     """Override: Managers get 10% bonus + extra per team member"""
    #     base_bonus = super().calculate_bonus()  # Call parent method
    #     team_bonus = self.__team_size * 500
    #     return base_bonus + team_bonus
    
    # Override display method
    def display_info(self):
        super().display_info()  # Call parent display
        print(f"Team Size: {self.__team_size} members")
        print(f"Management Bonus: +${self.__team_size * 500:,.2f}")
m=Manager("Bob", "M456", 90000, 5)
m.display_info()

# %%
class student:
    def __init__(self,name,roll,regno,adress):
        self.__name=name
        self._roll=roll
        self.__regno=regno
        self.adress=adress
    def grade(self,numbers):
        self.numbers=numbers
        if self.number>60:
            print("A")
        elif self.number<60 and self.number>40:
            print("B")
        else :
            print("C")
class monitor(student):
    def __init__(self, name, roll, regno, adress,monitor):
        super().__init__(name, roll, regno, adress)
        self.monitor =monitor
    def show(self):
