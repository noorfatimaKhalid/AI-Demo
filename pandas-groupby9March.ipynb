# %%
import pandas as pd
import numpy as np
df=pd.read_csv("D:\Python Notebooks\generic-food.csv")
#df.describe(include="all")
#df.duplicated().sum()
df['index']=range(1,len(df)+1)
df1=pd.read_csv("D:\Python Notebooks\data.csv")

df1['index']= range(1,len(df1)+1)
merge=pd.merge(df,df1,on='index',how='outer') 
#merge=merge.drop(columns=['Calories'], inplace=True)
#merge.groupby('GROUP')['Pulse'].sum()
df1
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\P'
# <>:7: SyntaxWarning: invalid escape sequence '\P'
# <>:3: SyntaxWarning: invalid escape sequence '\P'
# <>:7: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\People Links Laptop\AppData\Local\Temp\ipykernel_8684\823329950.py:3: SyntaxWarning: invalid escape sequence '\P'
#   df=pd.read_csv("D:\Python Notebooks\generic-food.csv")
# C:\Users\People Links Laptop\AppData\Local\Temp\ipykernel_8684\823329950.py:7: SyntaxWarning: invalid escape sequence '\P'
#   df1=pd.read_csv("D:\Python Notebooks\data.csv")
#     Duration          Date  Pulse  Maxpulse  Calories  index
# 0         60  '2020/12/01'    110       130     409.1      1
# 1         60  '2020/12/02'    117       145     479.0      2
# 2         60  '2020/12/03'    103       135     340.0      3
# 3         45  '2020/12/04'    109       175     282.4      4
# 4         45  '2020/12/05'    117       148     406.0      5
# ...

# %%
import matplotlib.pyplot as plt

df1['Maxpulse'].plot(kind='bar', title='Pulses')
plt.show()

# %%
merge.groupby('GROUP')['Pulse'].sum()
# Out:
# GROUP
# Animal foods                      0.0
# Aquatic foods                     0.0
# Baby foods                        0.0
# Baking goods                      0.0
# Beverages                         0.0
# Cereals and cereal products     108.0
# Cocoa and cocoa products          0.0
# Coffee and coffee products        0.0
# Confectioneries                   0.0
# Dishes                            0.0
# Eggs                              0.0
# Fats and oils                     0.0
# Fruits                          415.0
# Gourds                            0.0
# Herbs and Spices               1123.0
# Herbs and spices                  0.0
# Milk and milk products            0.0
# Nuts                            331.0
# Pulses                            0.0
# Snack foods                       0.0
# Soy                               0.0
# Teas                              0.0
# Unclassified                      0.0
# Vegetables                     1335.0
# Name: Pulse, dtype: float64

# %%
df1.groupby('Maxpulse')['Pulse'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Maxpulse'>
