# %% [markdown]
# LAMBDA FUNCTIONS

# %%
#SUM OF TWO NUMBERS
sum = lambda a,b : a+b
print(sum(2,3))
# Out:
# 5

# %%
#if number is even
sq = lambda n: n%2==0
print(sq(7))
# Out:
# False

# %%
#mapping a function(mapping is basically use as iteration, it traverse for each value in functon )
def myfunc(a, b):
  return a + b

x = list(map(myfunc, ('apple', 'banana', 'cherry'), ('orange', 'lemon', 'pineapple')))
print(x)
# Out:
# ['appleorange', 'bananalemon', 'cherrypineapple']

# %%
#returns if number is even if we actuallly want to print values not t/f
num=[1,2,3,5,6]
x=list(map(lambda n: n if n%2 !=0 else None,num))
print(x)
# Out:
# [1, None, 3, 5, None]

# %% [markdown]
# the major differenc between map and filter is ,filter actually stores value accordingto given operation while map usually return true false untill you modify the code. Map hamesha do arguments leta hai aik function dosra iterables raw materials

# %%
#sorting on the basis second index of pair
#sort function works on the basis of 2 index here, and asecending sort them.
p= [(3,6),(6,0),(3,4)]
p.sort(key=lambda x : x[1])
print(p)
#no index provided so sort first compare first index element if same, goes to next
k=[(5,6,7,8),(5,4,3,7),(1,2,0,7)]
k.sort( )
print(k)
#for descending order,
#  sort strictly follow positional arguments and keyword arguments rule of python in map and filter it does no make any issue as all i have used till now dont have keyword arguments so the dont make issue
num={4,74,3}
print(sorted(num,key=lambda x: -x))
# Out:
# [(6, 0), (3, 4), (3, 6)]
# [(1, 2, 0, 7), (5, 4, 3, 7), (5, 6, 7, 8)]
# [74, 4, 3]

# %%
num={9,5,'',5,None}
print(list(filter(None,num)))
#check for empty elements which is regarded as false, also repeated print for one time only
# Out:
# [9, 5]
