# %%
s = "Python"
print(s + " Language")
s * 2
print(s[0])
print(s[1:4])
print(len(s))
print(s.lower())
print(s.upper())
print(s.replace("Py","My"))
print("th" in s)
print(s *2)
# Out:
# Python Language
# P
# yth
# 6
# python
# PYTHON
# Mython
# True
# PythonPython

# %%
s = "Python"
print(s + " Language")
s * 2
print(s[0])
print(s[1:4])
print(len(s))
print(s.lower())
print(s.upper())
print(s.replace("Py","My"))
print("th" in s)
print(s *2)

# %% [markdown]
# input type casting

# %%
#name = input("Enter name: ")
#age = int(input("Enter age: "))
#height = float("5.9")
#num = str(100)
# This is a comment
x = int("10") + 5
y = float(5)
z = bool(1)
a = bool(0)
print("Hello", name)
print(z)
# Out:
# Hello
# True

# %%
d={"name" : "fatima", 'age' : 20}
print(d["age"])
print("name")
print(d["name"])
# Out:
# 20
# name
# fatima
