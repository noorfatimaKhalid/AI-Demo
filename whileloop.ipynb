# %%
#prints number skip 3
#i=1
#while i<5 :
    #if i==3 :
     # continue
    #print(i)
    #i+=1 
    # this is not printing rest of part after skipping 3 because continue neche wale part ko skip karva raha hai when i=3, and i never updates
i=0
while i<5 :
    i+=1
    if i==3 :
      continue
    print(i)
# Out:
# 1
# 2
# 4
# 5

# %%
#nested while loops 
i=1
while i<5 :
    j=1
    while j<2 :
        print(i,j)
        j+=1
       
    i+=1
# Out:
# 1 1
# 2 1
# 3 1
# 4 1

# %%
#variable args stored as tupple
def func(*num) :
    print (num)
func(4,6,4)
# Out:
# (4, 6, 4)

# %%
#arguments stored as dictionary
def func(**dic):
    print(dic)
func(name ="alic", age=20)
# Out:
# {'name': 'alic', 'age': 20}
