# %%
class student:
    def __init__(self,name,roll):
        self.__name = name
        self.roll = roll 
    def display(self) :
        print("name is ", self.__name, "roll is", self.roll)
    def get_name(self):
        
       return self.__name
    def get_roll(self):
        return self.roll
    def set_name(self, name):
        self.__name = name
    def set_roll(self, roll):
        self.roll = roll



s = student('Ali',1)
s.__name='alwi'

s.display()
print(s.get_name())
s.set_name('frman')
print(s.get_name())
# Out:
# name is  Ali roll is 1
# Ali
# frman

# %%
class  game:
    def __init__(self,name,working):
        self.__name= name
        self.working=working
    def display(self):
        print(self.__name,self.working)
    def get__name(self):
        return self.__name
    def set__name(self,name) :
        self.__name = name
    
obj=game("maijda","nothing")
#print(obj.get__name)
obj.display()
print(obj.get__name())
obj.set__name("fatima")
print(obj.get__name())
# Out:
# maijda nothing
# maijda
# fatima
